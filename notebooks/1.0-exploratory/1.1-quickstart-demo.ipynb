# %% [markdown]
# # 1.1 - SENTINEL Quick Start
#
# **Purpose**: Verify installation and test LLM capabilities
#
# **Author**: SENTINEL Developer
# **Date**: 2025-12-29
#
# ---
#
# ## Objectives
# 1. Import and test all major libraries
# 2. Test Ollama connection
# 3. Test LangChain RAG pipeline
# 4. Log experiment to MLflow

# %% [markdown]
# ## 1. Setup & Imports

# %%
# Standard libraries
import os
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Data science stack
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ML & MLOps
import mlflow
from sklearn.model_selection import train_test_split

# LLM & RAG
from langchain.llms import Ollama
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter

print("✅ All imports successful!")
# Out:
# -----------------------------
# ImportErrorTraceback (most recent call last)
# Cell In[1], line 14
#      11 import seaborn as sns
#      13 # ML & MLOps
# ---> 14 import mlflow
#      15 from sklearn.model_selection import train_test_split
#      17 # LLM & RAG
#
# File ~\Documents\SENTINEL PROJECT\venv\Lib\site-packages\mlflow\__init__.py:44
#      41 warnings.filterwarnings("ignore", message="numpy.dtype size changed")
#      42 warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
# ---> 44 from mlflow import (
#      45     artifacts,  # noqa: F401
#      46     client,  # noqa: F401
#      47     data,  # noqa: F401
#      48     exceptions,  # noqa: F401
#      49     models,  # noqa: F401
#      50     projects,  # noqa: F401
#      51     tracking,  # noqa: F401
#      52 )
#      54 # Lazily load mlflow flavors to avoid excessive dependencies.
#      55 catboost = LazyLoader("mlflow.catboost", globals(), "mlflow.catboost")
#
# File ~\Documents\SENTINEL PROJECT\venv\Lib\site-packages\mlflow\artifacts\__init__.py:11
#       9 from mlflow.exceptions import MlflowException
#      10 from mlflow.protos.databricks_pb2 import BAD_REQUEST, INVALID_PARAMETER_VALUE
# ---> 11 from mlflow.tracking import _get_store
#      12 from mlflow.tracking.artifact_utils import (
#      13     _download_artifact_from_uri,
#      14     add_databricks_profile_info_to_artifact_uri,
#      15     get_artifact_repository,
#      16 )
#      19 def download_artifacts(
#      20     artifact_uri: Optional[str] = None,
#      21     run_id: Optional[str] = None,
#    (...)     24     tracking_uri: Optional[str] = None,
#      25 ) -> str:
#
# File ~\Documents\SENTINEL PROJECT\venv\Lib\site-packages\mlflow\tracking\__init__.py:8
#       1 """
#       2 The ``mlflow.tracking`` module provides a Python CRUD interface to MLflow experiments
#       3 and runs. This is a lower level API that directly translates to MLflow
#       4 `REST API <../rest-api.html>`_ calls.
#       5 For a higher level API for managing an "active run", use the :py:mod:`mlflow` module.
#       6 """
# ----> 8 from mlflow.tracking._model_registry.utils import (
#       9     get_registry_uri,
#      10     set_registry_uri,
#      11 )
#      12 from mlflow.tracking._tracking_service.utils import (
#      13     _get_store,
#      14     get_tracking_uri,
#      15     is_tracking_uri_set,
#      16     set_tracking_uri,
#      17 )
#      18 from mlflow.tracking.client import MlflowClient
#
# File ~\Documents\SENTINEL PROJECT\venv\Lib\site-packages\mlflow\tracking\_model_registry\utils.py:15
#       2 from functools import partial
#       4 from mlflow.environment_variables import (
#       5     MLFLOW_REGISTRY_URI,
#       6     MLFLOW_TRACKING_AUTH,
#    (...)     13     MLFLOW_TRACKING_USERNAME,
#      14 )
# ---> 15 from mlflow.store._unity_catalog.registry.rest_store import UcModelRegistryStore
#      16 from mlflow.store.db.db_types import DATABASE_ENGINES
#      17 from mlflow.store.model_registry.databricks_workspace_model_registry_rest_store import (
#      18     DatabricksWorkspaceModelRegistryRestStore,
#      19 )
#
# File ~\Documents\SENTINEL PROJECT\venv\Lib\site-packages\mlflow\store\__init__.py:1
# ----> 1 from mlflow.store.artifact import artifact_repo
#       2 from mlflow.store.tracking import abstract_store
#       4 __all__ = [
#       5     # tracking server meta-data stores
#       6     "abstract_store",
#       7     # artifact repository stores
#       8     "artifact_repo",
#       9 ]
#
# File ~\Documents\SENTINEL PROJECT\venv\Lib\site-packages\mlflow\store\artifact\artifact_repo.py:8
#       5 from concurrent.futures import ThreadPoolExecutor, as_completed
#       6 from typing import List, Optional
# ----> 8 from mlflow.entities.file_info import FileInfo
#       9 from mlflow.entities.multipart_upload import CreateMultipartUploadResponse, MultipartUploadPart
#      10 from mlflow.environment_variables import MLFLOW_ENABLE_ARTIFACTS_PROGRESS_BAR
#
# File ~\Documents\SENTINEL PROJECT\venv\Lib\site-packages\mlflow\entities\__init__.py:6
#       1 """
#       2 The ``mlflow.entities`` module defines entities returned by the MLflow
#       3 `REST API <../rest-api.html>`_.
#       4 """
# ----> 6 from mlflow.entities.dataset import Dataset
#       7 from mlflow.entities.dataset_input import DatasetInput
#       8 from mlflow.entities.dataset_summary import _DatasetSummary
#
# File ~\Documents\SENTINEL PROJECT\venv\Lib\site-packages\mlflow\entities\dataset.py:4
#       1 from typing import Optional
#       3 from mlflow.entities._mlflow_object import _MLflowObject
# ----> 4 from mlflow.protos.service_pb2 import Dataset as ProtoDataset
#       5 from mlflow.utils.annotations import experimental
#       8 @experimental
#       9 class Dataset(_MLflowObject):
#
# File ~\Documents\SENTINEL PROJECT\venv\Lib\site-packages\mlflow\protos\service_pb2.py:11
#       9 from google.protobuf import reflection as _reflection
#      10 from google.protobuf import symbol_database as _symbol_database
# ---> 11 from google.protobuf import service as _service
#      12 from google.protobuf import service_reflection
#      13 # @@protoc_insertion_point(imports)
#
# ImportError: cannot import name 'service' from 'google.protobuf' (C:\Users\LENOVO\Documents\SENTINEL PROJECT\venv\Lib\site-packages\google\protobuf\__init__.py)

# %% [markdown]
# ## 2. Configuration

# %%
# Project configuration
CONFIG = {
    "project_root": Path.cwd().parent.parent,
    "data_dir": Path("../../data"),
    "models_dir": Path("../../models"),
    
    # MLflow
    "mlflow_uri": "http://localhost:5000",
    "experiment_name": "sentinel-quickstart",
    
    # Ollama
    "ollama_model": "llama3.1:8b-instruct-q4_K_M",
    "ollama_base_url": "http://localhost:11434",
    
    # Embeddings
    "embedding_model": "sentence-transformers/all-MiniLM-L6-v2",
    
    # Random seed
    "random_state": 42
}

# Set random seeds
np.random.seed(CONFIG["random_state"])

print("✅ Configuration loaded")
print(f"Project root: {CONFIG['project_root']}")

# %% [markdown]
# ## 3. Test Ollama Connection

# %%
# Initialize Ollama
llm = Ollama(
    model=CONFIG["ollama_model"],
    base_url=CONFIG["ollama_base_url"],
    temperature=0.1
)

# Test query
test_prompt = "Explain insider trading in 2 sentences."

print("🤖 Testing Ollama...")
print(f"Prompt: {test_prompt}")
print("\nResponse:")

response = llm(test_prompt)
print(response)

print("\n✅ Ollama is working!")

# %% [markdown]
# ## 4. Test Embedding Model

# %%
# Initialize embeddings
embeddings = HuggingFaceEmbeddings(
    model_name=CONFIG["embedding_model"]
)

# Test embedding
test_text = "POJK regulation about insider trading"
embedding_vector = embeddings.embed_query(test_text)

print(f"Text: {test_text}")
print(f"Embedding dimension: {len(embedding_vector)}")
print(f"First 5 values: {embedding_vector[:5]}")
print("\n✅ Embeddings working!")

# %% [markdown]
# ## 5. Simple RAG Demo

# %%
# Sample documents (simulating regulatory text)
sample_docs = [
    "Insider trading adalah praktik jual beli saham berdasarkan informasi material yang belum dipublikasikan.",
    "Orang dalam perusahaan dilarang melakukan transaksi saham dalam periode quiet period, yaitu 30 hari sebelum publikasi laporan keuangan.",
    "POJK 30/2016 mengatur tentang transaksi material dan benturan kepentingan.",
    "Bursa Efek Indonesia (BEI) mewajibkan pelaporan transaksi oleh orang dalam perusahaan.",
]

# Create text chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=200,
    chunk_overlap=20
)

chunks = text_splitter.create_documents(sample_docs)

print(f"Created {len(chunks)} chunks")
print("\n✅ Text splitting successful!")

# %%
# Create vector store
vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    collection_name="quickstart_demo"
)

print("✅ Vector store created!")

# Test similarity search
query = "Apa itu quiet period?"
docs = vectorstore.similarity_search(query, k=2)

print(f"\nQuery: {query}")
print("\nTop 2 relevant documents:")
for i, doc in enumerate(docs, 1):
    print(f"{i}. {doc.page_content}")

# %% [markdown]
# ## 6. RAG Query with LLM

# %%
from langchain.chains import RetrievalQA

# Create RAG chain
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever(search_kwargs={"k": 2}),
    return_source_documents=True
)

# Query
question = "Berapa lama quiet period sebelum publikasi laporan keuangan?"

print(f"Question: {question}")
print("\nProcessing...")

result = qa_chain({"query": question})

print("\n" + "="*50)
print("ANSWER:")
print("="*50)
print(result["result"])

print("\n" + "="*50)
print("SOURCE DOCUMENTS:")
print("="*50)
for i, doc in enumerate(result["source_documents"], 1):
    print(f"{i}. {doc.page_content}")

print("\n✅ RAG pipeline working!")

# %% [markdown]
# ## 7. Log Experiment to MLflow

# %%
# Set MLflow tracking URI
mlflow.set_tracking_uri(CONFIG["mlflow_uri"])
mlflow.set_experiment(CONFIG["experiment_name"])

with mlflow.start_run(run_name="quickstart-test"):
    # Log parameters
    mlflow.log_param("ollama_model", CONFIG["ollama_model"])
    mlflow.log_param("embedding_model", CONFIG["embedding_model"])
    mlflow.log_param("chunk_size", 200)
    mlflow.log_param("num_documents", len(sample_docs))
    
    # Log metrics
    mlflow.log_metric("embedding_dim", len(embedding_vector))
    mlflow.log_metric("num_chunks", len(chunks))
    
    # Log tags
    mlflow.set_tag("type", "quickstart")
    mlflow.set_tag("status", "success")
    
    print("✅ Experiment logged to MLflow!")
    print(f"\nView at: {CONFIG['mlflow_uri']}")

# %% [markdown]
# ## 8. Summary
#
# ### ✅ What We Tested:
# 1. **Imports** - All major packages working
# 2. **Ollama** - Local LLM inference working
# 3. **Embeddings** - Sentence transformers working
# 4. **RAG Pipeline** - Retrieval + generation working
# 5. **MLflow** - Experiment tracking working
#
# ### 🎯 Next Steps:
# 1. **Data Acquisition** - Collect real POJK PDFs
# 2. **Enhanced RAG** - Build production pipeline
# 3. **Model Training** - Train anomaly detection
# 4. **API Development** - Build FastAPI endpoints
#
# ### 📚 Resources:
# - **Roadmap**: `ROADMAP_QUANT_ENHANCED.md`
# - **Structure Guide**: `PROJECT_STRUCTURE_GUIDE.md`
# - **Quick Start**: `QUICKSTART.md`
#
# ---
#
# **Status**: ✅ Installation verified - Ready for development!
